# %% [markdown]
# ## Implementation of GRADCAM

# %% [markdown]
# Given below are the input parameters and the common images they share in the COCO dataset.

# %%
print("input-params:{}" .format(add_objects))
get_associated_objects_images(base_objects, add_objects)
# Out:
# input-params:['dog', 'phone']
# '3.551401869158879% of the images with car have dog, phone'

# %% [markdown]
#  ## Results
# These images below return a heatmap of what the network visualised to return these outputs. The first photo is that of a dog on top of a car and the subsequent images below are how the GradCam Algorithm step by step visualised the dog

# %%
#Code to read and display image from directory
img = cv2.imread('../images/474164.png')
plt.axis('off')
ax= plt.imshow(img)
plt.show(ax)

# %%
img = cv2.imread('cam.jpg')
plt.axis('off')
ax= plt.imshow(img)
plt.show(ax)

# %%
img = cv2.imread('gb.jpg')
plt.axis('off')
ax= plt.imshow(img)
plt.show(ax)

# %% [markdown]
# ### What does this image represent?
# We can see a final output of a dog highlighted by gradcam and a little bit of the car as well hence this image was returned when the input params were dog and car.

# %%
img = cv2.imread('cam_gb.jpg')
plt.axis('off')
ax= plt.imshow(img)
plt.show(ax)
